# %% [markdown]
# scoreboard for day:
#
# https://sports.yahoo.com/mlb/scoreboard/?date=2026-06-12
#
# example game ID: mlb.g.460613120
#
# corresponding API call: https://sports.yahoo.com/site/api/resource/sports.graphite.gameOdds;dataType=graphite;endpoint=graphite;gameIds=mlb.g.460613120

# %%
import re

import scrape_yahoo_mlb

SAMPLE_MLB_GAME = "mlb.g.460613120"

# url = scrape_yahoo.make_yahoo_json_url(SAMPLE_MLB_GAME)
# json_data = scrape_yahoo.get_some_json(url)
# parsed = scrape_yahoo.parse_yahoo_data(json_data)

scraper = scrape_yahoo_mlb.ScrapeYahooMLB()
scraper.cache_dir = "mlb_scrapes"
scraper.LEAGUE = "mlb"

# %%
# url = scraper.make_yahoo_json_url(SAMPLE_MLB_GAME)
# json_data = scraper.get_some_json(url)
# parsed = scraper.parse_yahoo_data(json_data)
# parsed
# Out:
# {'game_id': 'mlb.g.460613120',
#  'game_date': '2026-06-13-10:00',
#  'away_team': 'Seattle',
#  'home_team': 'Washington',
#  'pregame_odds': '-120, O/U 9',
#  'total_over_points': '9',
#  'total_over_stake_percentage': '3.93',
#  'total_over_wager_percentage': '6.63',
#  'total_over_odds': -113,
#  'total_over_decimal_odds': None,
#  'total_over_won': None,
#  'total_under_points': '9',
#  'total_under_stake_percentage': '96.07',
#  'total_under_wager_percentage': '93.37',
#  'total_under_odds': -107,
#  'total_under_decimal_odds': None,
#  'total_under_won': None,
#  'money_away_odds': -120,
#  'money_away_decimal_odds': None,
#  'money_away_stake_percentage': '26.25',
#  'money_away_wager_percentage': '42.96',
#  'money_away_won': None,
#  'money_home_odds': 100,
#  'money_home_decimal_odds': None,
#  'money_home_stake_percentage': '73.75',
#  'money_home_wager_percentage': '57.04',
#  'money_home_won': None,
#  'spread_away_points': '-1.5',
#  'spread_away_odds': 162,
#  'spread_away_decimal_odds': None,
#  'spread_away_stake_percentage': None,
#  'spread_away_wager_percentage': None,
#  'spread_away_won': None,
#  'spread_home_points': '1.5',
#  'spread_home_odds': -200,
#  'spread_home_decimal_odds': None,
#  'spread_home_stake_percentage': None,
#  'spread_home_wager_percentage': None,
#  'spread_home_won': None}

# %% [markdown]
# ok, so the problem is that this doesn't have the final scores so eg `money_over_won` are None
#
# the data is very limited as well, no bets at all on eg. `'spread_home_stake_percentage': None,`
#
# I will try another game ID.

# %%
# ANOTHER_MLB_GAME = "mlb.g.460613109"
# url = scraper.make_yahoo_json_url(ANOTHER_MLB_GAME)
# json_data = scraper.get_some_json(url)
# parsed = scraper.parse_yahoo_data(json_data)
# parsed
# Out:
# {'game_id': 'mlb.g.460613109',
#  'game_date': '2026-06-13-10:00',
#  'away_team': 'St. Louis',
#  'home_team': 'Minnesota',
#  'pregame_odds': '-116, O/U 9',
#  'total_over_points': '9',
#  'total_over_stake_percentage': '88.44',
#  'total_over_wager_percentage': '91.46',
#  'total_over_odds': -114,
#  'total_over_decimal_odds': None,
#  'total_over_won': None,
#  'total_under_points': '9',
#  'total_under_stake_percentage': '11.56',
#  'total_under_wager_percentage': '8.54',
#  'total_under_odds': -105,
#  'total_under_decimal_odds': None,
#  'total_under_won': None,
#  'money_away_odds': -103,
#  'money_away_decimal_odds': None,
#  'money_away_stake_percentage': '31.15',
#  'money_away_wager_percentage': '37.12',
#  'money_away_won': None,
#  'money_home_odds': -116,
#  'money_home_decimal_odds': None,
#  'money_home_stake_percentage': '68.85',
#  'money_home_wager_percentage': '62.88',
#  'money_home_won': None,
#  'spread_away_points': '1.5',
#  'spread_away_odds': -172,
#  'spread_away_decimal_odds': None,
#  'spread_away_stake_percentage': None,
#  'spread_away_wager_percentage': None,
#  'spread_away_won': None,
#  'spread_home_points': '-1.5',
#  'spread_home_odds': 142,
#  'spread_home_decimal_odds': None,
#  'spread_home_stake_percentage': None,
#  'spread_home_wager_percentage': None,
#  'spread_home_won': None}

# %% [markdown]
# 1. make URL to get all scores on date
# 2. parse out game IDs
# 3. collect stats by game ID.

# %% [markdown]
# ok, it's getting the MLB ID's now.

# %%
TEST_DATE = "2026-06-08"

scraper.get_yahoo_ids_for_date(TEST_DATE)
# Out:
# {'mlb.g.460608101',
#  'mlb.g.460608103',
#  'mlb.g.460608105',
#  'mlb.g.460608111',
#  'mlb.g.460608114',
#  'mlb.g.460608125',
#  'mlb.g.460608126',
#  'mlb.g.460608130'}

# %% [markdown]
# ok, the problem is a lot of these are totally missing data
#
# eg `mlb.g.460331119`

# %%
ANOTHER_MLB_GAME = "mlb.g.460613109"
url = scraper.make_yahoo_json_url(ANOTHER_MLB_GAME)
json_data = scraper.get_some_json(url)
parsed = scraper.parse_yahoo_data(json_data)
parsed
# Out:
# {'game_id': 'mlb.g.460613109',
#  'game_date': '2026-06-13-10:00',
#  'away_team': 'St. Louis',
#  'home_team': 'Minnesota',
#  'pregame_odds': '-117, O/U 9.5',
#  'total_over_points': '9.5',
#  'total_over_stake_percentage': '89.71',
#  'total_over_wager_percentage': '90.78',
#  'total_over_odds': -102,
#  'total_over_decimal_odds': None,
#  'total_over_won': None,
#  'total_under_points': '9.5',
#  'total_under_stake_percentage': '10.29',
#  'total_under_wager_percentage': '9.22',
#  'total_under_odds': -118,
#  'total_under_decimal_odds': None,
#  'total_under_won': None,
#  'money_away_odds': -103,
#  'money_away_decimal_odds': None,
#  'money_away_stake_percentage': '31.78',
#  'money_away_wager_percentage': '36.28',
#  'money_away_won': None,
#  'money_home_odds': -117,
#  'money_home_decimal_odds': None,
#  'money_home_stake_percentage': '68.22',
#  'money_home_wager_percentage': '63.72',
#  'money_home_won': None,
#  'spread_away_points': '1.5',
#  'spread_away_odds': -170,
#  'spread_away_decimal_odds': None,
#  'spread_away_stake_percentage': None,
#  'spread_away_wager_percentage': None,
#  'spread_away_won': None,
#  'spread_home_points': '-1.5',
#  'spread_home_odds': 140,
#  'spread_home_decimal_odds': None,
#  'spread_home_stake_percentage': None,
#  'spread_home_wager_percentage': None,
#  'spread_home_won': None}

# %% [markdown]
# data starts showing up around
# `mlb.g.460407126`

# %%
THIRD_MLB_GAME = "mlb.g.460413124"
url = scraper.make_yahoo_json_url(ANOTHER_MLB_GAME)
json_data = scraper.get_some_json(url)
parsed = scraper.parse_yahoo_data(json_data)
parsed
# Out:
# {'game_id': 'mlb.g.460613109',
#  'game_date': '2026-06-13-10:00',
#  'away_team': 'St. Louis',
#  'home_team': 'Minnesota',
#  'pregame_odds': '-113, O/U 9.5',
#  'total_over_points': '9.5',
#  'total_over_stake_percentage': '89.71',
#  'total_over_wager_percentage': '90.78',
#  'total_over_odds': -101,
#  'total_over_decimal_odds': None,
#  'total_over_won': None,
#  'total_under_points': '9.5',
#  'total_under_stake_percentage': '10.29',
#  'total_under_wager_percentage': '9.22',
#  'total_under_odds': -119,
#  'total_under_decimal_odds': None,
#  'total_under_won': None,
#  'money_away_odds': -106,
#  'money_away_decimal_odds': None,
#  'money_away_stake_percentage': '31.78',
#  'money_away_wager_percentage': '36.28',
#  'money_away_won': None,
#  'money_home_odds': -113,
#  'money_home_decimal_odds': None,
#  'money_home_stake_percentage': '68.22',
#  'money_home_wager_percentage': '63.72',
#  'money_home_won': None,
#  'spread_away_points': '1.5',
#  'spread_away_odds': -173,
#  'spread_away_decimal_odds': None,
#  'spread_away_stake_percentage': None,
#  'spread_away_wager_percentage': None,
#  'spread_away_won': None,
#  'spread_home_points': '-1.5',
#  'spread_home_odds': 143,
#  'spread_home_decimal_odds': None,
#  'spread_home_stake_percentage': None,
#  'spread_home_wager_percentage': None,
#  'spread_home_won': None}

# %% [markdown]
# ok, can I get previous seasons?

# %%
OLD_DATE = "2023-08-11"
scraper.get_yahoo_ids_for_date(OLD_DATE)
# Out:
# {'mlb.g.430811102',
#  'mlb.g.430811104',
#  'mlb.g.430811107',
#  'mlb.g.430811112',
#  'mlb.g.430811114',
#  'mlb.g.430811118',
#  'mlb.g.430811119',
#  'mlb.g.430811120',
#  'mlb.g.430811121',
#  'mlb.g.430811122',
#  'mlb.g.430811123',
#  'mlb.g.430811126',
#  'mlb.g.430811128',
#  'mlb.g.430811129',
#  'mlb.g.430811130'}

# %%
date_url = scraper.make_date_url("2024-08-11")

# %%
scraper.get_scraper().get(date_url).text
# Out:
# '{"data":{"leagues":[{"displayShort":"MLB","fullName":"mlb","name":"Major League Baseball","currentWeek":null,"currentGameSeasonPhase":"REGULAR_SEASON","currentLeagueSeason":[{"endDate":"2030-10-31T17:00:00-07:00","name":"2026","season":2026,"startDate":"2025-11-01T17:00:00-07:00"}],"games":[{"gameId":"mlb.g.440811120","startDate":"2024-08-11-07:00","startTime":"2024-08-11T08:35:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811102","startDate":"2024-08-11-07:00","startTime":"2024-08-11T10:35:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811110","startDate":"2024-08-11-07:00","startTime":"2024-08-11T10:35:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811114","startDate":"2024-08-11-07:00","startTime":"2024-08-11T10:37:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811128","startDate":"2024-08-11-07:00","startTime":"2024-08-11T10:40:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811130","startDate":"2024-08-11-07:00","startTime":"2024-08-11T10:40:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811108","startDate":"2024-08-11-07:00","startTime":"2024-08-11T11:10:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811109","startDate":"2024-08-11-07:00","startTime":"2024-08-11T11:10:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811127","startDate":"2024-08-11-07:00","startTime":"2024-08-11T12:10:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811126","startDate":"2024-08-11-07:00","startTime":"2024-08-11T13:05:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811119","startDate":"2024-08-11-07:00","startTime":"2024-08-11T13:10:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811129","startDate":"2024-08-11-07:00","startTime":"2024-08-11T13:10:00-07:00","status":"FINAL"},{"gameId":"mlb.g.440811112","startDate":"2024-08-11-07:00","startTime":"2024-08-11T16:10:00-07:00","status":"FINAL"}]}]},"extensions":{}}'

# %% [markdown]
# ah, too bad, doesn't seem to have percentages for those older ones

# %%
game_id = "mlb.g.430811130" # 2023-08-11

game_id = "mlb.g.430811120"

json_url = scraper.make_yahoo_json_url(game_id)
game_json = scraper.get_some_json(json_url)

game_json
# Out:
# {'data': {'games': [{'gameId': 'mlb.g.430811120',
#     'status': 'FINAL',
#     'startDate': '2023-08-11-10:00',
#     'startTime': '2023-08-11T13:05:00-10:00',
#     'gameOddsSummary': {'pregameOddsDisplay': '-120, O/U 9',
#      'favoriteId': 'mlb.t.20',
#      'underdogTeamPredictedScore': None,
#      'favoriteTeamPredictedScore': None},
#     'playoffSeries': None,
#     'league': {'shortName': 'MLB'},
#     'awayTeam': {'teamId': 'mlb.t.11',
#      'abbreviation': 'ATH',
#      'displayName': 'Athletics',
#      'nickname': 'Athletics',
#      'location': '',
#      'primaryColor': '003831',
#      'secondaryColor': 'efb21e',
#      'teamLogo': {'url': 'https://s.yimg.com/iu/api/res/1.2/2mGenGARVPMaPNpfSNFrAw--~B/YXBwaWQ9c2hhcmVkO2ZpPWZpbGw7cT03NTtoPTYwO3c9NjA-/https://s.yimg.com/cv/apiv2/default/mlb/20190319/500x500/oakland_a_wbgs.png'}},
#     'homeTeam': {'teamId': 'mlb.t.20',
#      'abbreviation': 'WAS',
#      'displayName': 'Washington',
#      'nickname': 'Nationals',
#      'location': 'Washington',
#      'primaryColor': '14225a',
#      'secondaryColor': 'ab0003',
#      'teamLogo': {'url': 'https://s.yimg.com/iu/api/res/1.2/3lXVdly92eKKfOOOVAeWhg--~B/YXBwaWQ9c2hhcmVkO2ZpPWZpbGw7cT03NTtoPTYwO3c9NjA-/https://s.yimg.com/cv/apiv2/default/mlb/20190402/500x500/nationals_wbgs.png'}},
#     'activePropBets': [],
#     'closedPropBets': [],
#     'gameLineSixPack': [],
#     'firstQuarterSixPack': [],
#     'secondQuarterSixPack': [],
#     'thirdQuarterSixPack': [],
#     'fourthQuarterSixPack': [],
#     'firstHalfSixPack': [],
#     'secondHalfSixPack': [],
#     'firstPeriodSixPack': [],
#     'secondPeriodSixPack': [],
#     'thirdPeriodSixPack': [],
#     'fiveInningsSixPack': [],
#     'gameNotes': [{'note': 'The over hit in 1 of the Oakland Athletics last 5 games in 2023',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The Oakland Athletics are 1-4 (20%) on the road in their last five games in 2023',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The Washington Nationals are 37-75 (33%) at home off a loss over their last 112 games',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The over hit in 4 of the Oakland Athletics last 5 games on the road in 2023',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The over hit in 4 of the Oakland Athletics last 5 games on the road in 2023',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The Oakland Athletics are 32-82 (28.1%) over their last 114 games',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The Oakland Athletics are 4-12 (25%) on the road over their last 16 games',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The over hit in 4 of the Oakland Athletics last 5 games on the road in 2023',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The Washington Nationals are 4-1 (80%) at home in their last five games in 2023',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The Oakland Athletics are 1-4 (20%) on the road over their last 5 games',
#       'provider': 'SPORTRADAR'},
#      {'note': 'The Oakland Athletics are 2-10 (16.7%) on the road over their last 12 games',
#       'provider': 'SPORTRADAR'}]}]},
#  'extensions': {}}
