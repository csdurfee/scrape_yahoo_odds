# %% [markdown]
# this is a scratchpad for figuring out to get data from yahoo. it probably isn't interesting, unless the final code has a bug in it

# %%
import pandas as pd

# %%
import requests

# %%
import bs4 as bs # beautifulsoup
import re

# %% [markdown]
# always worth a shot to see if read_html can do it

# %%
SAMPLE_URL = "https://sports.yahoo.com/nba/new-orleans-pelicans-philadelphia-76ers-2025011020/"

# %%
yah = pd.read_html(SAMPLE_URL)

# %%
yah
# Out:
# [  Final   1   2   3   4
#  0    SA  33  28  25  26
#  1   MIA  33  24  23  27,
#    Final   1   2   3   4
#  0   UTA  25  36  40  26
#  1   HOU  23  44  40  33,
#    Final   1   2   3   4
#  0   BOS  35  33  31  22
#  1   MEM  23  22  27  31,
#    Final   1   2   3   4
#  0   POR  39  34  24  26
#  1    GS  25  32  21  51,
#    Final   1   2   3   4
#  0   TOR  36  29  32  33
#  1   SAC  27  25  26  44]

# %% [markdown]
# (nope)

# %%
req = requests.get(SAMPLE_URL)
data = req.content

# %%
soup = bs.BeautifulSoup(data,'html.parser')

# %%
soup.find(class_="public-bet-wrapper")

# %%
soup.find(class_=re.compile("sportsbook-promo"))

# %%
# Out:
# <div class="ys-boxscore Bgc(#fff) Maw(924px) C(primary-text)" id="LeadLeft-0-Boxscore"><div class="ys-match-header ys-match-header-redesign"><div class="_ys_pnk1nr" data-l-type="media" data-m-type="media" data-s-type="normal" data-xl-type="media" data-xs-type="normal"><section class="_ys_1vv413w _ys_1caxt2h"><header class="_ys_1ceho82 _ys_1o13fsn" style="--ys-custom-left-color:#0c2340;--ys-custom-right-color:#006bb6"><div class="_ys_1qrprk7"><div class="_ys_1asg0eg"><div><a class="_ys_6ki3f7 _ys_6kguha" href="/nba/teams/new-orleans/" target="_blank"><div class="_ys_ejuhiy"><img alt="New Orleans" class="_ys_oc9ck" src="https://s.yimg.com/cv/apiv2/default/nba/20181226/70x70/pelicans.png"/><div class="_ys_5rgen4"><div class="_ys_1kvwhx0"><span class="_ys_6kd3wd _ys_fr53i8 _ys_1ob57ta">New Orleans</span><span class="_ys_6kzyql _ys_fr53i8">NO</span><span class="_ys_6kj1o9 _ys_p7vnzw"></span></div><div class="_ys_1g7fh1f _ys_p7vnzw">8-31</div></div></div></a></div></div><div class="_ys_1tw
# ...

# %%
main_soup = soup.find(id="LeadLeft-0-Boxscore")

# %%
str(main_soup).findall("Fz(12px)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 str(main_soup).findall("Fz(12px)")
#
# AttributeError: 'str' object has no attribute 'findall'

# %%
re.findall(r"Fz\(12px\)", str(main_soup))
# Out:
# ['Fz(12px)']

# %%
str(main_soup)[2500:2600]
# Out:
# 'iv class="D(tb) W(100%)"><div class="game-status D(tbc) W(35%) Fz(12px) Ta(c)"></div></div></div><di'

# %%
print(main_soup.prettify())
# Out:
# <div class="ys-boxscore Bgc(#fff) Maw(924px) C(primary-text)" id="LeadLeft-0-Boxscore">
#  <div class="ys-match-header ys-match-header-redesign">
#   <div class="_ys_pnk1nr" data-l-type="media" data-m-type="media" data-s-type="normal" data-xl-type="media" data-xs-type="normal">
#    <section class="_ys_1vv413w _ys_1caxt2h">
#     <header class="_ys_1ceho82 _ys_1o13fsn" style="--ys-custom-left-color:#0c2340;--ys-custom-right-color:#006bb6">
#      <div class="_ys_1qrprk7">
#       <div class="_ys_1asg0eg">
#        <div>
#         <a class="_ys_6ki3f7 _ys_6kguha" href="/nba/teams/new-orleans/" target="_blank">
#          <div class="_ys_ejuhiy">
#           <img alt="New Orleans" class="_ys_oc9ck" src="https://s.yimg.com/cv/apiv2/default/nba/20181226/70x70/pelicans.png"/>
#           <div class="_ys_5rgen4">
#            <div class="_ys_1kvwhx0">
#             <span class="_ys_6kd3wd _ys_fr53i8 _ys_1ob57ta">
#              New Orleans
#             </span>
# ...

# %% [markdown]
# unfortunately, it looks like the data is buried in some javascript which isn't easy to get out. I may need to go headless browser.

# %%
#!pip install pytest-playwright

# %%
import playwright

# %%
from playwright.sync_api import sync_playwright

# %%
sp = sync_playwright()

# %%
len(sp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 len(sp)
#
# TypeError: object of type 'PlaywrightContextManager' has no len()

# %%
sp

# %%
with sync_playwright() as p:
    p2 = p
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 with sync_playwright() as p:
#       2     p2 = p
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\playwright\sync_api\_context_manager.py:47, in PlaywrightContextManager.__enter__(self)
#      45             self._own_loop = True
#      46         if self._loop.is_running():
# ---> 47             raise Error(
#      48                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      49 Please use the Async API instead."""
#      50             )
#      52         # Create a new fiber for the protocol dispatcher. It will be pumping events
#      53         # until the end of times. We will pass control to that fiber every time we
# ...

# %%
# !pip install cloudscraper
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: C:\Users\casey\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# cloudscraper doesn't get blocked, but doesn't run the javascript either.
#
# this javascript has some data
#
# https://sports.yahoo.com/site/api/resource/sports.graphite.gameOdds;dataType=graphite;endpoint=graphite;gameIds=nba.g.2025011020?bkt=%5B%22prebid-ver9-53update-ctrl%22%2C%22sports_game_page_test%22%2C%22sports_game_page_opt_nfl_test%22%2C%22core-sports-team-newsdefault-copy%22%2C%22sports_game_page_opt_ncaaf_test%22%2C%22fantasy-next-app-ctrl%22%2C%22sports_game_page_opt_nhl_test%22%2C%22network_api_topic_page_control%22%5D&device=desktop&ecma=modern&feature=enableCMP%2CenableConsentData%2CenableGAMAds%2CenableGAMEdgeToEdge%2CenableScrollRestoration%2CfuseCss%2CincreaseStreamAdsTimeout%2Csp-nav-test%2CoathPlayer%2CenableEvPlayer%2CenableEVPlayer%2CenableSportsLiveDraftLobby%2CenableTaboolaLazyFetch%2CenableLiveDraftLobbyMockUsers%2CenableNewPremiumAdLogic%2CenableNextLDLSelection%2CenableComscoreUdm2%2CloadGameNotifs%2CdisableCommentsMessage%2CenableLGPD%2CenableHeaderBidding%2CenableNcpVideoChannel%2CenableBoxscoreRedesignPhase3%2CenableBoxscoreAds%2CenableMinihomeBranding%2CenableTaboolaAds%2CenableExperienceConfig%2CenableXrayNcp%2CenableXrayPeopleSportsEntities%2CenableXrayTeamEntities%2CenableXrayTopicEntities%2CenableXrayAthleteHeaderV2%2Clivecoverage%2CnewContentAttribution%2CenableChartbeat%2CenableHoneyPot%2CenableNextGenProgramming%2CenableVideoRedesign%2CsponsoredAds%2CenableRapidUloc%2CenableScorestripXSmallOnBoxscorePage%2CenableEntityStoryCardsNewAgeRanking%2CenableTeamTopNewsVideosModule%2CteamPageNewsAsDefaultTab&intl=us&lang=en-US&partner=none&prid=55c8v8hkeigoa&region=US&site=sports&tz=Pacific%2FHonolulu&ver=1.0.13177&returnMeta=true

# %%
some_url = """https://sports.yahoo.com/site/api/resource/sports.graphite.gameOdds;dataType=graphite;endpoint=graphite;gameIds=nba.g.2025011020?bkt=%5B%22prebid-ver9-53update-ctrl%22%2C%22sports_game_page_test%22%2C%22sports_game_page_opt_nfl_test%22%2C%22core-sports-team-newsdefault-copy%22%2C%22sports_game_page_opt_ncaaf_test%22%2C%22fantasy-next-app-ctrl%22%2C%22sports_game_page_opt_nhl_test%22%2C%22network_api_topic_page_control%22%5D&device=desktop&ecma=modern&feature=enableCMP%2CenableConsentData%2CenableGAMAds%2CenableGAMEdgeToEdge%2CenableScrollRestoration%2CfuseCss%2CincreaseStreamAdsTimeout%2Csp-nav-test%2CoathPlayer%2CenableEvPlayer%2CenableEVPlayer%2CenableSportsLiveDraftLobby%2CenableTaboolaLazyFetch%2CenableLiveDraftLobbyMockUsers%2CenableNewPremiumAdLogic%2CenableNextLDLSelection%2CenableComscoreUdm2%2CloadGameNotifs%2CdisableCommentsMessage%2CenableLGPD%2CenableHeaderBidding%2CenableNcpVideoChannel%2CenableBoxscoreRedesignPhase3%2CenableBoxscoreAds%2CenableMinihomeBranding%2CenableTaboolaAds%2CenableExperienceConfig%2CenableXrayNcp%2CenableXrayPeopleSportsEntities%2CenableXrayTeamEntities%2CenableXrayTopicEntities%2CenableXrayAthleteHeaderV2%2Clivecoverage%2CnewContentAttribution%2CenableChartbeat%2CenableHoneyPot%2CenableNextGenProgramming%2CenableVideoRedesign%2CsponsoredAds%2CenableRapidUloc%2CenableScorestripXSmallOnBoxscorePage%2CenableEntityStoryCardsNewAgeRanking%2CenableTeamTopNewsVideosModule%2CteamPageNewsAsDefaultTab&intl=us&lang=en-US&partner=none&prid=55c8v8hkeigoa&region=US&site=sports&tz=Pacific%2FHonolulu&ver=1.0.13177&returnMeta=true"""

# %%
import cloudscraper

# some_url = "https://stackoverflow.com/questions/77106304/playwright-force-useragent-for-headless-mode"

# some_url = "https://sports.yahoo.com/nba/new-orleans-pelicans-philadelphia-76ers-2025011020/"

scraper = cloudscraper.create_scraper()  # returns a CloudScraper instance
some_html = scraper.get(some_url).text

# %%
print(some_html)
# Out:
# {"data":{"data":{"games":[{"gameId":"nba.g.2025011020","status":"FINAL","startDate":"2025-01-10-10:00","startTime":"2025-01-10T14:00:00-10:00","gameOddsSummary":{"pregameOddsDisplay":"-7.5, O/U 219.5","favoriteId":"nba.t.20","underdogTeamPredictedScore":106,"favoriteTeamPredictedScore":113.5},"playoffSeries":null,"league":{"shortName":"NBA"},"awayTeam":{"teamId":"nba.t.3","abbreviation":"NO","displayName":"New Orleans","nickname":"Pelicans","location":"New Orleans","primaryColor":"0c2340","secondaryColor":"c8102e","teamLogo":{"url":"https://s.yimg.com/iu/api/res/1.2/vOcBf4BrdvIqZnp9RSjpvw--~B/YXBwaWQ9c2hhcmVkO2ZpPWZpbGw7cT0xMDA7aD02MDt3PTYw/https://s.yimg.com/cv/apiv2/default/nba/20181226/500x500/pelicans_wbg.png"}},"homeTeam":{"teamId":"nba.t.20","abbreviation":"PHI","displayName":"Philadelphia","nickname":"76ers","location":"Philadelphia","primaryColor":"006bb6","secondaryColor":"ed174c","teamLogo":{"url":"https://s.yimg.com/iu/api/res/1.2/8xtBYKInPjlVQu.PQrvV8g--~B/YXBwaWQ9c2hhcmV
# ...

# %%
import json

# %%
parsed = json.loads(some_html)

# %%
print(json.dumps(parsed, indent=4))

# %% [markdown]
# this is crap

# %%
some_html.find("width: 41")
# Out:
# -1

# %%
some_html[610690:620000]
# Out:
# 'NE":"Money Line","ODDS_MONEY_LINE_soccer":"Money Line","ODDS_MONEY_LINE_mlb":"Money Line","FIRST_HALF":"1st Half","SECOND_HALF":"2nd Half","FIRST_QUARTER":"1st Qtr","SECOND_QUARTER":"2nd Qtr","THIRD_QUARTER":"3rd Qtr","FOURTH_QUARTER":"4th Qtr","FIRST_PERIOD":"1st Per.","SECOND_PERIOD":"2nd Per.","THIRD_PERIOD":"3rd Per.","SHOOT_OUT_ABBR":"SO","FIRST_FIVE_INNINGS":"1st 5 Innings","FIRST_INNING":"1st Inning","ODDS_POINT_SPREAD":"Point Spread","ODDS_POINT_SPREAD_mlb":"Run Spread","ODDS_POINT_SPREAD_soccer":"Goal Spread","ODDS_TOTAL_POINTS":"Total Points","ODDS_TOTAL_POINTS_mlb":"Total Runs","ODDS_TOTAL_POINTS_soccer":"Total Goals","ODDS_MONEY_LINE_ABBR":"Money Ln","ODDS_MONEY_LINE_ABBR_soccer":"Money Ln","ODDS_MONEY_LINE_ABBR_mlb":"Money Ln","ODDS_POINT_SPREAD_ABBR":"Pt Spread","ODDS_POINT_SPREAD_ABBR_mlb":"Rn Spread","ODDS_POINT_SPREAD_ABBR_soccer":"G Spread","ODDS_TOTAL_POINTS_ABBR":"Total Pts","ODDS_TOTAL_POINTS_ABBR_mlb":"Total Rns","ODDS_TOTAL_POINTS_ABBR_soccer":"Total G","ODDS_
# ...

# %% [markdown]
# can we get the game ID from a calendar page with cloudscraper, then get the data from the JSON call?

# %%
game_id = "nba.g.2025011020"
date_url = "https://sports.yahoo.com/nba/scoreboard/?confId=&dateRange=2024-11-11"

scraper = cloudscraper.create_scraper()  # returns a CloudScraper instance
date_html = scraper.get(date_url).text

# %%
g_point = date_html.find('nba.g')

# %%
date_html[g_point-10:g_point+100]
# Out:
# '"GameItem-nba.g.2024111125"><div class="Bdc(#d8dade) Bds(s) Bdrs(4px) Bdc(card-border):h Bdw(1px)"><div><a hre'

# %%
import re

# %% [markdown]
# yeah, so these are the correct id's for the pages... now I need to see if I can reliably get the js associated with these id's, or if there are header issues/auth tokens, etc.

# %%
game_ids = set(re.findall(r"nba\.g\.2[\d]+", date_html))

# %%
game_ids
# Out:
# {'nba.g.2024111103',
#  'nba.g.2024111104',
#  'nba.g.2024111110',
#  'nba.g.2024111124',
#  'nba.g.2024111125'}

# %% [markdown]
# turns out, it works. good news, everybody

# %%
# import time
# for game_id in game_ids:
#     url = make_yahoo_json_url(game_id)
#     try_some_json(url)
#     time.sleep(5)

# %% [markdown]
# OK so now I need to go through each day:
#
#     get the ids from the calendar page
#     for each id:
#         save the json in a directory
#         do quick sanity check on it
#         parse the json into a dataframe

# %%
test_json
# Out:
# {'data': {'data': {'games': [{'gameId': 'nba.g.2025011020',
#      'status': 'FINAL',
#      'startDate': '2025-01-10-10:00',
#      'startTime': '2025-01-10T14:00:00-10:00',
#      'gameOddsSummary': {'pregameOddsDisplay': '-7.5, O/U 219.5',
#       'favoriteId': 'nba.t.20',
#       'underdogTeamPredictedScore': 106,
#       'favoriteTeamPredictedScore': 113.5},
#      'playoffSeries': None,
#      'league': {'shortName': 'NBA'},
#      'awayTeam': {'teamId': 'nba.t.3',
#       'abbreviation': 'NO',
#       'displayName': 'New Orleans',
#       'nickname': 'Pelicans',
#       'location': 'New Orleans',
#       'primaryColor': '0c2340',
#       'secondaryColor': 'c8102e',
#       'teamLogo': {'url': 'https://s.yimg.com/iu/api/res/1.2/vOcBf4BrdvIqZnp9RSjpvw--~B/YXBwaWQ9c2hhcmVkO2ZpPWZpbGw7cT0xMDA7aD02MDt3PTYw/https://s.yimg.com/cv/apiv2/default/nba/20181226/500x500/pelicans_wbg.png'}},
#      'homeTeam': {'teamId': 'nba.t.20',
#       'abbreviation': 'PHI',
# ...

# %%
test_json.keys()
# Out:
# dict_keys(['data', 'meta'])

# %%
# this is data for the over/under

test_json['data']['data']['games'][0]['gameLineSixPack'][0]['options']
# Out:
# [{'id': 644086623,
#   'name': 'Over 219.5',
#   'americanOdds': -110,
#   'decimalOdds': '1.910',
#   'shortName': 'O 219.5',
#   'displayName': 'O 219.5',
#   'status': 'CLOSED',
#   'teamIds': [],
#   'isCorrect': True,
#   'optionDetails': [{'key': 'over', 'value': '219.5'}],
#   'stakePercentage': '70.37',
#   'wagerPercentage': '76.78'},
#  {'id': 644086624,
#   'name': 'Under 219.5',
#   'americanOdds': -110,
#   'decimalOdds': '1.910',
#   'shortName': 'U 219.5',
#   'displayName': 'U 219.5',
#   'status': 'CLOSED',
#   'teamIds': [],
#   'isCorrect': False,
#   'optionDetails': [{'key': 'under', 'value': '219.5'}],
#   'stakePercentage': '29.63',
#   'wagerPercentage': '23.22'}]

# %%
test_json['data']['data']['games'][0]['gameOddsSummary']['underdogTeamPredictedScore']
# Out:
# 106

# %% [markdown]
# current question: do these game id's match up with something I could get from eg basketball-reference or NBA API?
#
# answer: no, they don't. NBA API id's are weird (for instance 2024 games start with "22", and basketball-reference has its own schema)

# %%
yahoo_game_id = "nba.g.2025011020"

# %%
#!pip install --upgrade jsonpath-ng
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: C:\Users\casey\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from jsonpath_ng.ext import parse

# %% [markdown]
# test_json['data']['data']['games'][0]['gameOddsSummary']['underdogTeamPredictedScore']

# %% [markdown]
# "eventState": "PREGAME",

# %%
expression = parse('$.data.data.games[0].gameLineSixPack[?type = "OVER_UNDER" & eventState = "PREGAME"].options[0].stakePercentage')

# %%
import pprint

# %%
k = expression.find(test_json)

# %%
k.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 k.value
#
# AttributeError: 'list' object has no attribute 'value'

# %%
[x.value for x in expression.find(test_json)]
# Out:
# ['70.37']

# %%
with open("C:/code/book/yahoo/nba.g.2024102202.json") as f:
    foo = json.load(f)

# %%
import glob

# %%
glob.glob("yahoo/*.json")
# Out:
# ['yahoo\\nba.g.2024102202.json',
#  'yahoo\\nba.g.2024102213.json',
#  'yahoo\\nba.g.2024102301.json',
#  'yahoo\\nba.g.2024102303.json',
#  'yahoo\\nba.g.2024102308.json',
#  'yahoo\\nba.g.2024102310.json',
#  'yahoo\\nba.g.2024102312.json',
#  'yahoo\\nba.g.2024102314.json',
#  'yahoo\\nba.g.2024102320.json',
#  'yahoo\\nba.g.2024102322.json',
#  'yahoo\\nba.g.2024102326.json',
#  'yahoo\\nba.g.2024102328.json',
#  'yahoo\\nba.g.2024102406.json',
#  'yahoo\\nba.g.2024102407.json',
#  'yahoo\\nba.g.2024102423.json',
#  'yahoo\\nba.g.2024102427.json',
#  'yahoo\\nba.g.2024102501.json',
#  'yahoo\\nba.g.2024102505.json',
#  'yahoo\\nba.g.2024102510.json',
#  'yahoo\\nba.g.2024102513.json',
#  'yahoo\\nba.g.2024102515.json',
#  'yahoo\\nba.g.2024102518.json',
#  'yahoo\\nba.g.2024102519.json',
#  'yahoo\\nba.g.2024102522.json',
#  'yahoo\\nba.g.2024102526.json',
#  'yahoo\\nba.g.2024102528.json',
#  'yahoo\\nba.g.2024102604.json',
#  'yahoo\\nba.g.2024102607.json',
# ...

# %%
foo = pd.read_csv("yahoo/2024_odds.csv")

# %%
foo
# Out:
#       Unnamed: 0           game_id         game_date      away_team  \
# 0              0  nba.g.2024102202  2024-10-22-10:00       New York
# 1              1  nba.g.2024102213  2024-10-22-10:00      Minnesota
# 2              2  nba.g.2024102301  2024-10-23-10:00       Brooklyn
# 3              3  nba.g.2024102303  2024-10-23-10:00        Chicago
# 4              4  nba.g.2024102308  2024-10-23-10:00        Indiana
# ...          ...               ...               ...            ...
# 1257        1257  nba.g.2025042429  2025-04-24-10:00  Oklahoma City
# 1258        1258  nba.g.2025042515  2025-04-25-10:00        Indiana
# 1259        1259  nba.g.2025042516  2025-04-25-10:00      LA Lakers
# 1260        1260  nba.g.2025042519  2025-04-25-10:00         Boston
# 1261        1261  nba.g.2025101020  2025-10-10-10:00        Orlando
#
#          home_team     pregame_odds  over_points  over_stake_percentage  \
# 0           Boston  -5.5, O/U 221.5        221.5                  89.22
# ...

# %%
foo.loc[foo.home_spread_stake_percentage.idxmin()]
# Out:
# Unnamed: 0                                   538
# game_id                         nba.g.2025010730
# game_date                       2025-01-07-10:00
# away_team                                Phoenix
# home_team                              Charlotte
# pregame_odds                     -4.5, O/U 226.5
# over_points                                226.5
# over_stake_percentage                      71.26
# over_wager_percentage                      67.19
# over_odds                                 -105.0
# over_decimal_odds                           1.95
# under_points                               226.5
# under_stake_percentage                     28.74
# under_wager_percentage                     32.81
# under_odds                                -115.0
# under_decimal_odds                          1.87
# away_money_odds                           -200.0
# away_money_decimal_odds                      1.5
# away_money_stake_percentage                94.07
# ...
